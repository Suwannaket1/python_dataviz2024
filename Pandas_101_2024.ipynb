# %% [markdown]
# <a href="https://colab.research.google.com/github/Suwannaket1/python_dataviz2024/blob/main/Pandas_101_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3], 'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3], 'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# #Load pandas data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
folk_df = pd.read_csv('/content/folktales.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c1fdb6158f43> in <cell line: 1>()
# ----> 1 folk_df = pd.read_csv('/content/folktales.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# #Load pandas data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os #os จัดการ path กับ file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_folktales = '/content/drive/MyDrive/data_viz_2024_DATA/folktales.csv'

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.head() #ดูข้อมูลหัวตารางคร่าวๆ
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df.tail() #ดูข้อมูลท้ายตารางคร่าวๆ
# Out:
#                    title             type                 creator  \
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# ...

# %%
folk_df.shape
# Out:
# (226, 11)

# %% [markdown]
# ## ชี้ค่าในตาราง
# ชี้ไปที่ column ก่อน ค่อยชี้ว่าเป็นตัวไหนใน list

# %%
folk_df['title'][99]
# Out:
# 'เด็กโง่'

# %%
folk_df['creator'][99]
# Out:
# 'เรียบ รักสมบัติ'

# %% [markdown]
# #### .iloc (เปลี่ยนมุมมองของ DataFrame เป็น array

# %%
folk_df.iloc[99,6] #[แถว,หลัก]
# Out:
# nan

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title',	'type',	'creator', 'subject',	'spatia']]
smaller_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-acaf8bfcf53d> in <cell line: 1>()
# ----> 1 smaller_table = folk_df[['title',       'type', 'creator', 'subject',   'spatia']]
#       2 smaller_table
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ...

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# #####มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
folk_df.iloc[1:5,:] #ตัด row ที่ 1-4, เอาทุก olumns
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# ##Table Query
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ### อยากได้นิทานที่เป็นมุขตลก

# %%
#list ของ logic
folk_df['type']=='มุขตลก'
#มันจะไปเลือก True
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 221    False
# 222     True
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df[folk_df['type']=='มุขตลก']
# Out:
#                                           title    type              creator  \
# 3                                     บักหำน้อย  มุขตลก      สมหวัง ปานพายัพ
# 4                                    รื้อบ่อน้ำ  มุขตลก       บุญศรี เกสเสโร
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ  มุขตลก   พัชราภรณ์ เข็มเพชร
# 7                                หลวงพ่อน้องงัว  มุขตลก      สุบิน คำยางจ้อง
# 8                             หลวงพ่อกับเณรน้อย  มุขตลก  ปรางค์ทิพย์ บุญสีลา
# 9                               หัวล้านหลื่นครู  มุขตลก        ใจมา สมจันทร์
# 11            เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ  มุขตลก     เพ็ญนภา พันพินิจ
# 18                                       จับราว  มุขตลก          ชารี คำสีมา
# 19                               บักแหมบกับอีทา  มุขตลก      สุนีย์ คุณโพธิ์
# 20                             แม่เฒ่ากับลูกเขย  มุขตลก      สุนีย์ คุณโพธิ์
# 22                            หลวงพ่อกลัวผีหลอก  มุขตลก          เสาร์ จันกอ
# ...

# %% [markdown]
# ####Quiz6 เลือก data มา 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logic ในการ query
#
# แสดงวิธีทำดังนี้
# 1.สร้าง list of logics
# 2.query

# %%
# 1.สร้าง list of logics
logic_list = [True]*10 + [False]*(folk_df.shape[0]-25) + [True]*15

# 2.Query
result = folk_df[logic_list]
result
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %%
result.shape
# Out:
# (25, 11)

# %%
#เฉลย
list_logic1 = [True]*10
list_logic2 = [True]*15

# %%
list_lodM = (226-10-15) * [False]

# %%
folk_df[list_logic1 + list_lodM + list_logic2]
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# #HW5
#
# ใช้การ Query และ Data Slicing เพื่อตอบคำถามต่อไปนี้
#
# 1. นิทานที่ยาวที่สุดและสั้นที่สุด (ไม่นับสัญลักษณ์พิเศษ)
# 2. ชนิดของนิทาน (Type) ที่มากที่สุดและน้อยที่สุด
# 3. มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][0]

# %% [markdown]
# ##1.นิทานที่ยาวที่สุดและสั้นที่สุด (ไม่นับสัญลักษณ์พิเศษ)

# %%
import re

longest_story_title = ""
shortest_story_title = ""
longest_length = 0
shortest_length = float('inf')

description_index = None
title_index = None

# หา index ของ column 'description' และ 'title'
for i, column_name in enumerate(folk_df.columns):
    if column_name == 'description':
        description_index = i
    elif column_name == 'title':
        title_index = i

# หานิทานที่ยาวที่สุดและสั้นที่สุด
for i in range(len(folk_df)):
    story = folk_df.iloc[i, description_index]
    if isinstance(story, str):
        # ใช้ regular expression เพื่อกรองเฉพาะตัวอักษรภาษาไทย
        thai_chars = re.findall(r'[\u0E00-\u0E7F]', story)
        story_length = len(thai_chars)
    else:
        story_length = 0

    if story_length > longest_length:
        longest_length = story_length
        longest_story_title = folk_df.iloc[i, title_index]

    if story_length < shortest_length:
        shortest_length = story_length
        shortest_story_title = folk_df.iloc[i, title_index]

print("นิทานที่ยาวที่สุด:", longest_story_title, "(จำนวนตัวอักษรไม่รวมเว้นวรรค:", longest_length, ")")
print("นิทานที่สั้นที่สุด:", shortest_story_title, "(จำนวนตัวอักษรไม่รวมเว้นวรรค:", shortest_length, ")")
# Out:
# นิทานที่ยาวที่สุด: ท้าวหมาหยุ๋ย (จำนวนตัวอักษรไม่รวมเว้นวรรค: 7739 )
# นิทานที่สั้นที่สุด: บอดตาใส (จำนวนตัวอักษรไม่รวมเว้นวรรค: 0 )

# %% [markdown]
# ##2.ชนิดของนิทาน (Type) ที่มากที่สุดและน้อยที่สุด

# %%
# หาชนิดของนิทานที่ไม่ซ้ำกัน
unique_types = []
for i in range(len(folk_df)):
    story_type = folk_df.iloc[i, folk_df.columns.get_loc('type')]
    if story_type not in unique_types:
        unique_types.append(story_type)

# นับจำนวนชนิดของนิทานแต่ละชนิด
type_counts = {}
for type_name in unique_types:
    count = 0
    for i in range(len(folk_df)):
        if folk_df.iloc[i, folk_df.columns.get_loc('type')] == type_name:
            count += 1
    type_counts[type_name] = count

# หาชนิดของนิทานที่มากที่สุดและน้อยที่สุด
most_common_type = ""
least_common_type = ""
most_count = 0
least_count = float('inf')

for type_name, count in type_counts.items():
    if count > most_count:
        most_count = count
        most_common_type = type_name
if count < least_count:
        least_count = count
        least_common_type = type_name

print("ชนิดของนิทานที่มากที่สุด:", most_common_type, "(จำนวน:", most_count,")")
print("ชนิดของนิทานที่น้อยที่สุด:", least_common_type, "(จำนวน:", least_count,")")
# Out:
# ชนิดของนิทานที่มากที่สุด: มุขตลก (จำนวน: 51 )
# ชนิดของนิทานที่น้อยที่สุด: นิทานเข้าแบบ (จำนวน: 1 )

# %% [markdown]
# ##3.มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
non_thai_count = 0
for i in range(len(folk_df)):
    spatial = folk_df.iloc[i, folk_df.columns.get_loc('spatial')]
    if spatial != "ไทย":
        non_thai_count += 1

print("จำนวนเรื่องที่ spatial ไม่ใช่ 'ไทย':", non_thai_count)
# Out:
# จำนวนเรื่องที่ spatial ไม่ใช่ 'ไทย': 146

# %% [markdown]
# ## เฉลย ข้อที่ 1

# %%
# prompt: ลบ row ที่มีค่าว่างใน coulumn description

folk_df = folk_df.dropna(subset=['description'])

# %%
# prompt: ลบ html  tags และ html codes ออกจาก text ใน column description ใช้ beautifulSoup

from bs4 import BeautifulSoup

def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    clean_text = soup.get_text()
    return clean_text

folk_df['description'] = folk_df['description'].apply(remove_html_tags)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0          มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่...  นิทานพื้นบ้าน     ไทย
# 1        ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครอ...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['description'][0]
# Out:
# '\xa0 \xa0 \xa0 \xa0 มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า\n\xa0 \xa0 \xa0 \xa0"เราจะพาไปตั้งวงดนตรีจะไปไหม?" "เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ"\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งพูดขึ้นมาว่า\xa0\xa0"นายจะร้องได้ไหม?"\n\xa0 \xa0 \xa0 \xa0 อีกคนตอบ "มันจะยากอะไร"\n\xa0 \xa0 \xa0 \xa0 เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า\n\xa0 \xa0 \xa0 \xa0"หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย"\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า "นั่นช้างหรอ"\n\xa0 \xa0 \xa0 \xa0 ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง\xa0เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน\n\xa0 \xa0 \xa0 \xa0 ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า\n\xa0 \xa0 \xa0 \xa0 "โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย"\n\xa0 \xa0 \xa0 \xa0 คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า\n\xa0 \xa0 \xa0 \xa0 "ช้างนี่เหมือนสูบตีเหล็กนะ"\n\xa0 \xa0 \xa0 \xa0\xa0คนที่สามเข้ามาทางด้านข้างของ
# ...

# %%
# prompt: description ของ row ไหนยาวที่สุดและสั้นที่สุด  print name และ ความยาว

longest_description = ''
shortest_description = None
longest_description_title = ''
shortest_description_title = ''

for i in range(len(folk_df)):
  description = folk_df.iloc[i, folk_df.columns.get_loc('description')]
  if description:
    if not shortest_description or len(description) < len(shortest_description):
      shortest_description = description
      shortest_description_title = folk_df.iloc[i, folk_df.columns.get_loc('title')]
    if len(description) > len(longest_description):
      longest_description = description
      longest_description_title = folk_df.iloc[i, folk_df.columns.get_loc('title')]

print("Longest description:", longest_description_title, "(length:", len(longest_description), ")")
print("Shortest description:", shortest_description_title, "(length:", len(shortest_description), ")")
# Out:
# Longest description: ท้าวหมาหยุ๋ย (length: 7831 )
# Shortest description: จักจั่นไม่มีไส้ (length: 205 )

# %% [markdown]
# #เฉลย ข้อที่ 2

# %%
# prompt: ลบค่าว่างใน column type

folk_df = folk_df.dropna(subset=['type'])

# %%
# prompt: ชนิดของนิทานที่มีจำนวน row มากที่สุดและน้อยที่สุด

# Count the occurrences of each type
type_counts = folk_df['type'].value_counts()

# Find the type with the maximum and minimum count
most_common_type = type_counts.idxmax()
least_common_type = type_counts.idxmin()

# Print the results
print("Most common type:", most_common_type, "(count:", type_counts[most_common_type], ")")
print("Least common type:", least_common_type, "(count:", type_counts[least_common_type], ")")
# Out:
# Most common type: มุขตลก (count: 46 )
# Least common type: นิทานเข้าแบบ (count: 1 )

# %% [markdown]
# ##ทำเอง

# %%
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          40       22           40       40       34         0
# นิทานประจำถิ่น      25       14           25       25       23         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          14        5           14       14       11         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              46       31           46       46       42         0
#
#                  language  rights  license  source.uri
# type
# ...

# %% [markdown]
# ### HW5 มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
folk_df['spatial'].unique() #unique คือ อะไรที่มันซ้ำกัน จะยุบรวม
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
set(folk_df['spatial']) # set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df = folk_df.dropna(subset=['spatial'])

# %%
folk_df.shape
# Out:
# (192, 11)

# %%
eight_rows_covid = data_covid.iloc[:8,:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7    8     1/26/2020  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 10 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 10 columns]

# %% [markdown]
# HW (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้หญิง และผู้ชาย ของผู้ป่วยในจังหวัดขอนแก่น

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data = folk_df.copy()

# %%
this_data.shape #(12423, 3)
# Out:
# (192, 11)

# %%
print(this_data.shape)
print(this_data.dropna().shape)
#ข้อเสียdropna data หายไป 100% เพราะมันไม่ได้เลือก
# Out:
# (192, 11)
# (0, 11)

# %%
this_data = folk_df.copy()

# %%
this_data.dropna(inplace=True)

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = this_data.dropna(inplace=True) #มันเป็นฟังก์ชันที่จบในตัวมันอยู่แล้ว ไม่ได้ return อะไร จะเป็นค่า None

# %%
this_data #ตัวที่มารับก็จะเป็น None

# %% [markdown]
# ## ลบเฉพาะค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.copy()

# %%
this_data = folk_df.dropna(subset='title') #สมมติเราต้องใช้ค่าใน column

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) #สมมติเราต้องใช้ค่าใน column

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['type'].mode()
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ##ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull() #ช่องไหน null จะเป็น True/ ไม่ใช่ null จะเป็น False
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any() #มันจะ OR ค่าความจริงทั้งหมดใน list
#วิธีเช็คว่ามีช่องไหนเป็น True หรือ False
# Out:
# False

# %%
folk_df['type'].isnull().all() #เอาทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any() #แสดงว่ามีค่าว่างอยู่ใน spatial
# Out:
# True

# %% [markdown]
# #Quiz 7-8
# นิทานเรื่องไหนที่ค่า spatial เป็นค่าว่าง (ไม่ใช้ Gemini)

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %%
folk_df['title'][223]
# Out:
# 'เต่ากับพระพุทธเจ้า'

# %% [markdown]
# ## ลบค่าซ้ำ

# %%
# prompt: หาค่าซ้ำใน column title

import pandas as pd

# Create a DataFrame
folk_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/folktales.csv')

# Find duplicate values in the 'title' column
duplicate_titles = folk_df[folk_df['title'].duplicated()]

# Print the duplicate values
print(duplicate_titles)
# Out:
#                   title            type             creator  \
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# 43   <p>ชาวนาครอบครัวหนึ่งในจังหวัดยโสธร มีแม่กับลู...  นิทานพื้นบ้าน     ไทย
# 75   <p>พญาคันคาก เป็นราชาครองเมืองชมพู บรรดาบ้านเม...  นิทานพื้นบ้าน     NaN
# 95   <p>ขณะที่รอการเก็บเกี่ยวข้าว ท้าวกำพร้าได้ออกข...  นิทานพื้นบ้าน    ไทย,
# 100  <p>ท้าวขี้คร้านไม่ทำการทำงานได้แต่ขออาหารชาวบ้...  นิทานพื้นบ้าน    ไทย,
# ...

# %%
folk_df['title'].duplicated()
# Out:
#                   title            type             creator  \
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# 43   <p>ชาวนาครอบครัวหนึ่งในจังหวัดยโสธร มีแม่กับลู...  นิทานพื้นบ้าน     ไทย
# 75   <p>พญาคันคาก เป็นราชาครองเมืองชมพู บรรดาบ้านเม...  นิทานพื้นบ้าน     NaN
# 95   <p>ขณะที่รอการเก็บเกี่ยวข้าว ท้าวกำพร้าได้ออกข...  นิทานพื้นบ้าน    ไทย,
# 100  <p>ท้าวขี้คร้านไม่ทำการทำงานได้แต่ขออาหารชาวบ้...  นิทานพื้นบ้าน    ไทย,
# ...

# %%
folk_df[folk_df['title'].duplicated(keep=False)] #จะเจอว่ามันซ้ำกันมากแค่ไหน
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.fillna({'type':folk_df['type'].mode()})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %% [markdown]
# การทำให้แต่ละ row ถูกมองเป็นสมาชิกใน list

# %%
this_data = folk_df[['title','type','creator']].dropna()

# %%
this_data
# Out:
#                        title             type                 creator
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 217                   เณรทอง   นิทานประจำถิ่น         รมย์   เผือกแสง
# 218         ดวงอาทิตย์กับไก่  นิทานอธิบายเหตุ         รมย์   เผือกแสง
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
#
# [125 rows x 3 columns]

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# *************************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# *************************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# *************************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# *************************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# *************************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# *************************
# (6, title        ตำนานกุดนางใย
# ...

# %% [markdown]
# #Quiz9.1
#
# *   วนลูปนับว่ามีนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องกี่เรื่อง เรื่องอะไรบ้าง
# *   มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
# *   คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่องว่า แม่ หรือ พ่อ มากที่สุด

# %%
# prompt: วนลูปนับว่ามีนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องกี่เรื่อง เรื่องอะไรบ้าง
# มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน เท่าไหร่
# คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่องว่า แม่ หรือ พ่อ มากที่สุด

# นับจำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง
count_mom_dad = 0
mom_dad_stories = []
count_life_stories = 0
count_local_stories = 0
creator_counts = {} #กำหนด dictionary ให้ว่างๆก่อน

for _, row in this_data.iterrows():
    title = row['title']
    story_type = row['type']
    creator = row['creator']

    if 'แม่' in title or 'พ่อ' in title:
        count_mom_dad += 1
        mom_dad_stories.append(title)

        if story_type == 'นิทานชีวิต':
            count_life_stories += 1
        elif story_type == 'นิทานประจำถิ่น':
            count_local_stories += 1

        if creator in creator_counts:
            creator_counts[creator] += 1
        else:
            creator_counts[creator] = 1

# หาคนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่า 'แม่' หรือ 'พ่อ' มากที่สุด
most_frequent_creator = max(creator_counts, key=creator_counts.get)

print("1.จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง:", count_mom_dad)
print("- รายชื่อนิทาน:", mom_dad_stories)
print("2.1 จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง และเป็นนิทานชีวิต:", count_life_stories)
print("2.2 จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง และเป็นนิทานประจำถิ่น:", count_local_stories)
print("3. คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่า 'แม่' หรือ 'พ่อ' มากที่สุด:", most_frequent_creator)
# Out:
# 1.จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง: 19
# - รายชื่อนิทาน: ['ก่องข้าวน้อยฆ่าแม่', 'หลวงพ่อน้องงัว', 'หลวงพ่อกับเณรน้อย', 'แม่ใหญ่แฮก', 'ปัญญาของพ่อ', 'แม่เฒ่ากับลูกเขย', 'หลวงพ่อกลัวผีหลอก', 'หลวงพ่อเข้าลอดช่อง', 'ลูกหลงพ่อ', 'ก่องข้าวน้อยฆ่าแม่', 'คนจีนกับหลวงพ่อเจ้าอาวาส', 'หลวงพ่อกินขี้ไก่โป่', 'หลวงพ่อม้าน้อยหลังแอ่น', 'พ่อเฒ่ากับลูกเขยกินข้าวนำกัน', 'พ่อใหญ่หัวล้าน', 'หลวงพ่อกะทอเกลือ', 'แม่หม้ายตาโป', 'ด้ามมีดพ่อท่าน', 'พระคุณแม่โพสพ']
# 2.1 จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง และเป็นนิทานชีวิต: 2
# 2.2 จำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่อง และเป็นนิทานประจำถิ่น: 2
# 3. คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่า 'แม่' หรือ 'พ่อ' มากที่สุด: หนูเวียง แก้วเวียง

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9.2 print ชื่อนิทานทั้งหมดที่มีคำว่า 'ปู่' ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า 'ปู่'  ออกมา โดยใช้ iloc

count = 0
for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
    count += 1
print(f"มีนิทานที่มีคำว่าปู่ทั้งหมด {count} เรื่อง")
# Out:
# เขาปู่เขาย่า
# มีนิทานที่มีคำว่าปู่ทั้งหมด 1 เรื่อง

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_movie = '/content/drive/MyDrive/data_viz_2024_DATA/IMDb_Movies_India.csv'

# %%
movie_df = pd.read_csv(path_to_movie, encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: หลังจาก dropna แล้ว ข้อมูลหายไปกี่ %

movie_df = pd.read_csv(path_to_movie, encoding='latin-1')
original_size = movie_df.shape[0]
after_dropna = movie_df.dropna().shape[0]
percent_lost = ((original_size - after_dropna) / original_size) * 100
print(f"ข้อมูลหายไป {percent_lost:.2f}%")
# Out:
# ข้อมูลหายไป 63.51%

# %%
movie_df = movie_df.dropna()

# %%
# ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
# prompt: สร้างตารางของผู้กำกับที่มีหนังเยอะที่สุด เอาเฉพาะข้อมูลในคอลัมน์ต่างๆคนที่มีหนังเยอะที่สุดมา

# นับจำนวนหนังของผู้กำกับแต่ละคน
director_counts = movie_df['Director'].value_counts()

# หาผู้กำกับที่มีหนังเยอะที่สุด
most_prolific_directors = director_counts.index[:10]  # สมมติว่าต้องการ 10 อันดับแรก

# สร้างตารางใหม่สำหรับผู้กำกับที่มีหนังเยอะที่สุด
most_prolific_df = movie_df[movie_df['Director'].isin(most_prolific_directors)]

# แสดงตาราง
print(most_prolific_df)
# Out:
#                            Name  Year  Duration                      Genre  \
# 22                   12 O'Clock  2021       105           Horror, Thriller
# 38                         1920  2008       138   Horror, Mystery, Romance
# 41                         1921  2018       144   Horror, Mystery, Romance
# 239                 Aag Ka Gola  1990       180              Action, Drama
# 275                         Aaj  1987       116                      Drama
# ...                         ...   ...       ...                        ...
# 15235  Yeh Hai Mumbai Meri Jaan  1999       148    Action, Comedy, Romance
# 15290     Yeh To Kamaal Ho Gaya  1982       136      Action, Comedy, Drama
# 15311        Your Home, My Home  2001       175              Comedy, Drama
# 15341                     Zakhm  1998       125                      Drama
# 15494                  Zubeidaa  2001       153  Biography, Drama, History
#
#        Rating  Votes           Director             Actor 1  \
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %% [markdown]
# #HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง

# %%
# นับจำนวนหนังของผู้กำกับแต่ละคน
director_counts = movie_df['Director'].value_counts()

# เลือกผู้กำกับ 3 คนแรกที่มีหนังเยอะที่สุด
top_3_directors_count = director_counts.head(3)

# สร้าง DataFrame ใหม่สำหรับผู้กำกับ 3 คนแรก
top_3_df = movie_df[movie_df['Director'].isin(top_3_directors_count.index)]

# คำนวณค่าเฉลี่ยของคะแนน (Rating) สำหรับผู้กำกับแต่ละคน
average_ratings = top_3_df.groupby('Director')['Rating'].mean().sort_values(ascending=False) # sort by rating

# แสดงจำนวนหนังที่เยอะสุด 3 อันดับแรก
output_string = "ผู้กำกับที่มีจำนวนหนังเยอะที่สุด 3 อันดับแรก ได้แก่\n"
for i, (director, count) in enumerate(top_3_directors_count.items()):
    output_string += f"{director} จำนวน {count} เรื่อง"
    if i == 0:
        output_string += ", "
    elif i == 1:
        output_string += " และ "
print(output_string)

# แสดงค่าเฉลี่ย rating 3 อันดับแรก
output_string = "\nและเมื่อพิจารณาดูค่าเฉลี่ย Rating หนังของผู้กำกับทุกคนแล้ว พบว่า ผู้กำกับ 3 อันดับแรกที่มีค่าเฉลี่ย rating หนังสูงสุด ได้แก่\n"
for i, (director, rating) in enumerate(average_ratings.items()):
    output_string += f"{director} มีค่าเฉลี่ย {rating:.2f}"  # formatting to 2 decimal places
    if i == 0:
        output_string += ", "
    elif i == 1:
        output_string += " และ "
print(output_string)

# สรุป
output_string = "\nสรุป ผู้กำกับชั้นนำของอินเดีย 3 คน ได้แก่\n"
for i, (director, rating) in enumerate(average_ratings.items()):
    count = top_3_directors_count[director]
    output_string += f"{director} ซึ่งมีจำนวนหนังทั้งหมด {count} เรื่อง (มีค่าเฉลี่ย Rating {rating:.2f})"
    if i == 0:
        output_string += ",\n"
    elif i == 1:
        output_string += "\nและ "
print(output_string)
# Out:
# ผู้กำกับที่มีจำนวนหนังเยอะที่สุด 3 อันดับแรก ได้แก่
# David Dhawan จำนวน 41 เรื่อง, Mahesh Bhatt จำนวน 39 เรื่อง และ Ram Gopal Varma จำนวน 33 เรื่อง
#
# และเมื่อพิจารณาดูค่าเฉลี่ย Rating หนังของผู้กำกับทุกคนแล้ว พบว่า ผู้กำกับ 3 อันดับแรกที่มีค่าเฉลี่ย rating หนังสูงสุด ได้แก่
# Mahesh Bhatt มีค่าเฉลี่ย 5.75, Ram Gopal Varma มีค่าเฉลี่ย 5.60 และ David Dhawan มีค่าเฉลี่ย 5.23
#
# สรุป ผู้กำกับชั้นนำของอินเดีย 3 คน ได้แก่
# Mahesh Bhatt ซึ่งมีจำนวนหนังทั้งหมด 39 เรื่อง (มีค่าเฉลี่ย Rating 5.75),
# Ram Gopal Varma ซึ่งมีจำนวนหนังทั้งหมด 33 เรื่อง (มีค่าเฉลี่ย Rating 5.60)
# และ David Dhawan ซึ่งมีจำนวนหนังทั้งหมด 41 เรื่อง (มีค่าเฉลี่ย Rating 5.23)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
