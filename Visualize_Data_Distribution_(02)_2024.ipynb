# %% [markdown]
# <a href="https://colab.research.google.com/github/Suwannaket1/python_dataviz2024/blob/main/Visualize_Data_Distribution_(02)_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การแสดงผลการกระจายของข้อมูล

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ## Scatter 2D

# %% [markdown]
# ## scatter - default
# scatter : กระจัดกระจาย

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %% [markdown]
# ### color

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c='r')

# %% [markdown]
# ## ใส่สีให้แต่ละจุด

# %%
set(df['Name']) #ดูว่ามีค่าอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
df2
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %% [markdown]
# ### alpha กำหนดความโปร่งแสง

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ใช้ขนาดของ marker แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=10*df['SepalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=100,c=df2['Name'],alpha=0.5,marker='$f$')

# %% [markdown]
# ## การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='$S$')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='$E$')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='$I$')

# %% [markdown]
# ###Label-Legend

# %% [markdown]
# ```plt.plot()``` input  ตัวที่ 3 คือ ตัวกำหนดหน้าตาของ marker
#
# 'หน้าตาmarker'-'ลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o:r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right')

# %% [markdown]
# ### การใส่ชื่อกราฟ และชื่อแกน

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right')
plt.title('Iris flower data distribution') ##ชื่อกราฟ
plt.xlabel('PetalLength') ##ชื่อแกน X
plt.ylabel('PetalWidth'); ##ชื่อแกน y

# %% [markdown]
# ### 3D scatter

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ## Bubble Chart
#
# Scatter plot ที่ใช้ขนาดของ marker ในการสื่อปริมาณของข้อมูล

# %%
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=180*df['SepalWidth'][100:],c='r')

# %% [markdown]
# ### Example

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_excel('/content/passenger-covid19.xlsx')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-bc428e9fe8b7> in <cell line: 1>()
# ----> 1 data = pd.read_excel('/content/passenger-covid19.xlsx')
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     if not isinstance(io, ExcelFile):
#     503         should_close = True
# --> 504         io = ExcelFile(
#     505             io,
#     506             storage_options=storage_options,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561                 ext = "xls"
#    1562             else:
# -> 1563                 ext = inspect_excel_format(
#    1564                     content_or_path=path_or_buffer, storage_options=storage_options
#    1565                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1417         content_or_path = BytesIO(content_or_path)
#    1418
# -> 1419     with get_handle(
#    1420         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1421     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     870         else:
#     871             # Binary mode
# --> 872             handle = open(handle, ioargs.mode)
#     873         handles.append(handle)
#     874
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/passenger-covid19.xlsx'

# %%
data_drop = data.dropna()
data_drop

# %%
0.001 * data_drop.iloc[:3,6]

# %%
import numpy as np
import matplotlib

# %%
matplotlib.rcParams['figure.figsize']=[8,5]

# %%
plt.scatter([0,100,200],[200,200,200],s=list(0.001*data_drop.iloc[:3,6]),alpha=0.5)
plt.xlim((-50,300));

# %% [markdown]
# ### Box-plot

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
O = plt.boxplot(df['SepalWidth'])

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7922e6de4640>,
#   <matplotlib.lines.Line2D at 0x7922e6de48e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7922e6de4b80>,
#   <matplotlib.lines.Line2D at 0x7922e6de4e20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7922e6de43a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7922e6de50c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7922e6de5360>],
#  'means': []}

# %%
O['fliers'][0].get_ydata()
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7922e6e43370>,
#   <matplotlib.lines.Line2D at 0x7922e6e43610>],
#  'caps': [<matplotlib.lines.Line2D at 0x7922e6e438b0>,
#   <matplotlib.lines.Line2D at 0x7922e6e43b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7922e6e43280>],
#  'medians': [<matplotlib.lines.Line2D at 0x7922e6e43df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7922e6e74370>],
#  'means': [<matplotlib.lines.Line2D at 0x7922e6e740d0>]}

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %% [markdown]
# *   เปรียบเทียบ boxplot ของดอกไม้หลายๆชนิด

# %% [markdown]
# #HW7 plot กราฟแสดงการกระจายของข้อมูลใน india imdb และ มาพรีเซ้นเป็นกลุ่ม (2 กราฟ)

# %% [markdown]
# #นำเข้าข้อมูล

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_movie = '/content/drive/MyDrive/data_viz_2024_DATA/IMDb_Movies_India.csv'

# %%
movie_df = pd.read_csv(path_to_movie, encoding='latin-1')
movie_df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %% [markdown]
# #จัดการข้อมูล

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
#ตรวจสอบค่า null
movie_df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
movie_df = movie_df.dropna(subset=['Rating', 'Votes','Duration'])

# %%
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)
movie_df['Votes'] = movie_df['Votes'].str.replace(',', '')
# Out:
# <ipython-input-9-3ea375ecc81f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)
# <ipython-input-9-3ea375ecc81f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)
# <ipython-input-9-3ea375ecc81f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Votes'] = movie_df['Votes'].str.replace(',', '')

# %%
# ตรวจสอบและแปลงคอลัมน์ Votes เป็น float
movie_df['Votes'] = pd.to_numeric(movie_df['Votes'], errors='coerce')
# Out:
# <ipython-input-10-cdd5c73ce1e2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Votes'] = pd.to_numeric(movie_df['Votes'], errors='coerce')

# %%
movie_df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# 6            Drama, Romance, War     7.4   1086   Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326    Allyson Patel
# ...                          ...     ...    ...              ...
# 15493                      Drama     6.1    408      Mozez Singh
# 15494  Biography, Drama, History     6.2   1496    Shyam Benegal
# 15503       Action, Crime, Drama     5.8     44  S.P. Muthuraman
# 15505              Action, Drama     4.5    655       Kuku Kohli
# 15508              Action, Drama     6.2     20     K.C. Bokadia
#
#                Actor 1                 Actor 2           Actor 3
# 1         Rasika Dugal          Vivek Ghamande     Arvind Jangid
# 3              Prateik              Ishita Raj   Siddhant Kapoor
# 5           Bobby Deol  Aishwarya Rai Bachchan     Shammi Kapoor
# 6      Jimmy Sheirgill          Minissha Lamba    Yashpal Sharma
# 8            Yash Dave          Muntazir Ahmad      Kiran Bhatia
# ...                ...                     ...               ...
# 15493    Vicky Kaushal         Sarah Jane Dias  Raaghavv Chanana
# 15494   Karisma Kapoor                   Rekha    Manoj Bajpayee
# 15503      Chiranjeevi              Jayamalini       Rajinikanth
# 15505     Akshay Kumar          Twinkle Khanna       Aruna Irani
# 15508       Dharmendra              Jaya Prada       Arjun Sarja
#
# [5851 rows x 10 columns]

# %%
movie_df.shape
# Out:
# (5851, 10)

# %%
#หลังdropnaแล้วข้อมูลเหลือกี่%จากเดิม

print(f"ข้อมูลเหลือ {(len(movie_df) / len(pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb_Movies_India.csv', encoding='latin-1'))) * 100:.2f}% จากเดิม")
# Out:
# ข้อมูลเหลือ 37.73% จากเดิม

# %%
movie_df.duplicated().sum()
# Out:
# 0

# %%
movie_df.isnull().sum()
# Out:
# Name          0
# Year          0
# Duration      0
# Genre        31
# Rating        0
# Votes         0
# Director      1
# Actor 1      75
# Actor 2     117
# Actor 3     163
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# แยกประเภทหนังในคอลัมน์ Genre และเลือกประเภทแรกที่พบ
movie_df['Primary Genre'] = movie_df['Genre'].str.split(',').str[0]

# ดูประเภทหนังที่ไม่ซ้ำกัน
unique_genres = movie_df['Primary Genre'].unique()

# แสดงจำนวนและประเภทหนังที่ไม่ซ้ำกัน
print(f"จำนวนประเภทหนังทั้งหมด: {len(unique_genres)}")
print("ประเภทหนังที่ไม่ซ้ำกัน:")
print(unique_genres)
# Out:
# จำนวนประเภทหนังทั้งหมด: 21
# ประเภทหนังที่ไม่ซ้ำกัน:
# ['Drama' 'Comedy' 'Horror' 'Action' 'Crime' 'Thriller' 'Adventure' 'Sport'
#  'Biography' 'Documentary' 'Mystery' 'Musical' 'Romance' 'Fantasy'
#  'Sci-Fi' 'Family' 'History' 'Animation' nan 'War' 'Music']
# <ipython-input-17-c1d4aec5ee13>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Primary Genre'] = movie_df['Genre'].str.split(',').str[0]

# %%
# สร้าง index สำหรับแทนที่ประเภทหนังด้วยตัวเลข
genre_to_num = {genre: idx for idx, genre in enumerate(movie_df['Primary Genre'].unique())}
movie_df['Genre_Num'] = movie_df['Primary Genre'].map(genre_to_num)

# สรุปข้อมูล
summary = movie_df.groupby('Primary Genre').agg({
    'Rating': ['mean', 'median', 'min', 'max', 'count']
}).sort_values(('Rating', 'mean'), ascending=False)

summary.columns = ['Average Rating', 'Median Rating', 'Min Rating', 'Max Rating', 'Number of Movies']
summary = summary.reset_index()
summary
# Out:
# <ipython-input-18-8cc77333b5cb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Genre_Num'] = movie_df['Primary Genre'].map(genre_to_num)
#    Primary Genre  Average Rating  Median Rating  Min Rating  Max Rating  \
# 0    Documentary        7.586154           7.70         4.1         9.3
# 1          Music        7.466667           6.80         5.9         9.7
# 2        History        7.333333           7.10         6.0         9.4
# 3      Biography        6.697619           6.95         2.4         8.9
# 4         Family        6.391228           6.40         2.6         9.3
# 5         Sci-Fi        6.320000           6.30         4.3         9.3
# 6          Drama        6.255253           6.50         1.6        10.0
# 7        Fantasy        6.251613           6.60         2.4         8.0
# 8      Adventure        6.181905           6.50         2.4         8.4
# 9          Crime        6.132721           6.40         2.1         8.9
# 10       Musical        6.095556           6.55         1.8         8.2
# 11     Animation        6.014286           6.25         2.3         8.6
# 12       Mystery        5.883607           6.20         2.7         8.8
# 13        Comedy        5.844121           6.10         1.6         9.3
# 14         Sport        5.800000           5.80         5.5         6.1
# 15       Romance        5.612500           5.70         1.8         8.6
# 16        Action        5.513907           5.60         1.1         9.2
# 17      Thriller        5.330435           5.50         2.5         8.7
# 18        Horror        4.696899           4.60         1.9         8.0
# 19           War        4.333333           3.50         2.8         6.7
#
#     Number of Movies
# 0                130
# 1                  3
# 2                  9
# 3                 84
# 4                 57
# 5                  5
# 6               1875
# 7                 31
# 8                105
# 9                272
# 10                90
# 11                56
# 12                61
# 13               995
# 14                 2
# 15               160
# 16              1661
# 17                92
# 18               129
# 19                 3

# %%
# หา Genre ที่มีค่าเฉลี่ย Rating สูงสุดและต่ำสุด
top_genre = summary.iloc[0]
bottom_genre = summary.iloc[-1]

print(f"\nGenre ที่มีค่าเฉลี่ย Rating สูงสุด: {top_genre['Primary Genre']} (Average Rating: {top_genre['Average Rating']:.2f})")
print(f"Genre ที่มีค่าเฉลี่ย Rating ต่ำสุด: {bottom_genre['Primary Genre']} (Average Rating: {bottom_genre['Average Rating']:.2f})")

# หา Genre ที่มีจำนวนหนังมากที่สุดและน้อยที่สุด
most_movies = summary.loc[summary['Number of Movies'].idxmax()]
least_movies = summary.loc[summary['Number of Movies'].idxmin()]

print(f"\nGenre ที่มีจำนวนหนังมากที่สุด: {most_movies['Primary Genre']} ({most_movies['Number of Movies']} movies)")
print(f"Genre ที่มีจำนวนหนังน้อยที่สุด: {least_movies['Primary Genre']} ({least_movies['Number of Movies']} movies)")

# คำนวณค่าเฉลี่ย Rating ทั้งหมด
overall_avg_rating = movie_df['Rating'].mean()
print(f"\nค่าเฉลี่ย Rating ของหนังทั้งหมด: {overall_avg_rating:.2f}")
# Out:
# Genre ที่มีค่าเฉลี่ย Rating สูงสุด: Documentary (Average Rating: 7.59)
# Genre ที่มีค่าเฉลี่ย Rating ต่ำสุด: War (Average Rating: 4.33)
#
# Genre ที่มีจำนวนหนังมากที่สุด: Drama (1875 movies)
# Genre ที่มีจำนวนหนังน้อยที่สุด: Sport (2 movies)
#
# ค่าเฉลี่ย Rating ของหนังทั้งหมด: 5.93

# %% [markdown]
# #กราฟที่ 1

# %%
# กำหนดจำนวนของ Genre ในข้อมูล
num_genres = movie_df['Primary Genre'].nunique()

# สร้างพาเลทสีที่มีจำนวนสีเท่ากับจำนวน Genre
palette = sns.color_palette('YlOrRd', num_genres)

# ใช้พาเลทสีที่กำหนด
sns.boxplot(
    x='Primary Genre',
    y='Rating',
    data=movie_df,
    palette=palette  # ใช้พาเลทสีที่กำหนดเอง
)

# ตั้งชื่อและป้ายกำกับกราฟ
plt.title('Distribution of Ratings by Genre', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# แสดงกราฟ
plt.show()
# Out:
# <ipython-input-20-b866163c516f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# สร้าง Scatter Plot ด้วย Plotly
fig = px.scatter(
    movie_df,
    x='Rating',
    y='Votes',
    color='Primary Genre',  # ใช้สีเพื่อแยกประเภท
    hover_name='Name',  # แสดงชื่อภาพยนตร์เมื่อ hover
    hover_data={'Year': True, 'Genre': True, 'Duration': True, 'Rating': True, 'Votes': True, 'Primary Genre': True},
    title='Scatter Plot of Rating vs. Votes',
    labels={'Rating': 'Rating', 'Votes': 'Votes'},
    color_discrete_sequence=px.colors.qualitative.D3  # กำหนดสีเป็น D3
)

# ปรับแต่งกราฟ
fig.update_layout(
    xaxis_title='Rating',
    yaxis_title='Votes',
    template='plotly_white'
)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9f6f63a-c516-4c74-8bbb-2387ae56e4ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9f6f63a-c516-4c74-8bbb-2387ae56e4ed")) {                    Plotly.newPlot(                        "b9f6f63a-c516-4c74-8bbb-2387ae56e4ed",                        [{"customdata":[[2019,"Drama",109,"Drama"],[2005,"Drama, Romance, War",142,"Drama"],[2004,"Drama",96,"Drama"],[2009,"Drama, Horror, Mystery",146,"Drama"],[2005,"Drama",116,"Drama"],[1993,"Drama",168,"Drama"],[2004,"Drama",94,"Drama"],[2012,"Drama, Horror, Romance",124,"Drama"],[1979,"Drama, History",121,"Drama"],[1974,"Drama",115,"Drama"],[2018,"Drama",100,"Drama"],[1981,"Drama, Romance",122,"Drama"],[2019,"Drama",93,"Drama"],[2011,"Drama, Mystery, Thriller",121,"Drama"],[2016,"Drama",75,"Drama"],[2012,"Drama, Family, Musical",113,"Drama"],[2007,"Drama",92,"Drama"],[2011,"Drama, Mystery, Thriller",137,"Drama"],[1987,"Drama, Horror, Musical",127,"Drama"],[2016,"Drama",105,"Drama"],[2017,"Drama",145,"Drama"],[2016,"Drama, Thriller",110,"Drama"],[2010,"Drama, Horror, Romance",103,"Drama"],[2019,"Drama, Romance",95,"Drama"],[2013,"Drama",127,"Drama"],[2005,"Drama, Romance",143,"Drama"],[2019,"Drama",104,"Drama"],[2018,"Drama",121,"Drama"],[2016,"Drama",120,"Drama"],[2019,"Drama",107,"Drama"],[1982,"Drama",154,"Drama"],[1950,"Drama, Romance",115,"Drama"],[1968,"Drama, Romance",175,"Drama"],[1969,"Drama, Romance, Thriller",168,"Drama"],[1993,"Drama, Romance",158,"Drama"],[2009,"Drama",78,"Drama"],[1977,"Drama, Family",138,"Drama"],[1953,"Drama, Musical, Romance",150,"Drama"],[1993,"Drama, Romance",149,"Drama"],[1977,"Drama",150,"Drama"],[1987,"Drama",116,"Drama"],[1963,"Drama, Romance",144,"Drama"],[2007,"Drama, Family, Music",137,"Drama"],[1968,"Drama, Romance",121,"Drama"],[1966,"Drama",153,"Drama"],[1975,"Drama, History, Romance",139,"Drama"],[2018,"Drama, Family",107,"Drama"],[1984,"Drama",130,"Drama"],[1970,"Drama, Musical, Romance",177,"Drama"],[2003,"Drama",160,"Drama"],[1975,"Drama, Romance",133,"Drama"],[1985,"Drama",144,"Drama"],[1952,"Drama",136,"Drama"],[1990,"Drama",145,"Drama"],[2019,"Drama",94,"Drama"],[1972,"Drama, Romance",154,"Drama"],[1976,"Drama, Family",145,"Drama"],[1964,"Drama, Family, Romance",128,"Drama"],[2011,"Drama, Thriller",164,"Drama"],[1974,"Drama",129,"Drama"],[1999,"Drama, Romance",175,"Drama"],[1980,"Drama, Musical, Romance",123,"Drama"],[2010,"Drama",120,"Drama"],[2005,"Drama, Romance, Thriller",115,"Drama"],[2013,"Drama, Music, Musical",132,"Drama"],[2011,"Drama, Romance",109,"Drama"],[1968,"Drama",146,"Drama"],[2014,"Drama",132,"Drama"],[2009,"Drama",240,"Drama"],[1984,"Drama, Mystery",145,"Drama"],[1965,"Drama",172,"Drama"],[1966,"Drama, Family",161,"Drama"],[1997,"Drama",132,"Drama"],[2013,"Drama, Horror, Thriller",100,"Drama"],[1974,"Drama, Romance",107,"Drama"],[1957,"Drama",133,"Drama"],[1994,"Drama, Romance",127,"Drama"],[2013,"Drama, Music",160,"Drama"],[1968,"Drama, Romance",141,"Drama"],[1973,"Drama, Musical",122,"Drama"],[1970,"Drama, Romance",154,"Drama"],[1984,"Drama",132,"Drama"],[1936,"Drama, Musical, Romance",142,"Drama"],[1958,"Drama, Musical, Romance",139,"Drama"],[2007,"Drama",88,"Drama"],[1955,"Drama",150,"Drama"],[2017,"Drama, Family, Horror",106,"Drama"],[1983,"Drama",122,"Drama"],[2016,"Drama, Music, Musical",158,"Drama"],[1966,"Drama, Romance",134,"Drama"],[1951,"Drama, Family",168,"Drama"],[2001,"Drama, Romance",195,"Drama"],[1991,"Drama, Romance",145,"Drama"],[1983,"Drama, Family",161,"Drama"],[1985,"Drama, Crime",138,"Drama"],[1996,"Drama, Musical, Romance",142,"Drama"],[2002,"Drama, Fantasy, Romance",126,"Drama"],[2009,"Drama, Horror, Mystery",130,"Drama"],[1995,"Drama",145,"Drama"],[2006,"Drama, Romance",122,"Drama" ...

# %%
# ข้อมูลค่าเฉลี่ย
avg_data = movie_df.groupby('Primary Genre')[['Rating', 'Votes']].median().reset_index()

# สร้างกราฟ scatter plot ด้วย Plotly
fig = px.scatter(
    avg_data,
    x='Rating',
    y='Votes',
    color='Primary Genre',  # สีแยกตาม Primary Genre
    size='Votes',  # ขนาดของฟองอากาศตามจำนวน Votes
    size_max=60,  # ขนาดสูงสุดของฟองอากาศ (ปรับให้เล็กลง)
    hover_name='Primary Genre',  # ข้อมูลที่แสดงเมื่อ hover
    hover_data={'Rating': True, 'Votes': True},  # ข้อมูลเพิ่มเติมที่แสดงเมื่อ hover
    title='Median Rating and Votes by Genre',
    labels={'Rating': 'Med Rating', 'Votes': 'Med Votes'},
    color_discrete_sequence=px.colors.qualitative.D3  # กำหนดสีเป็น D3
)

# ปรับแต่ง Layout
fig.update_layout(
    xaxis_title='Med Rating',
    yaxis_title='Med Votes',
    template='plotly_white'
)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4d45aeed-f414-4478-887c-9a4e61ce6182" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d45aeed-f414-4478-887c-9a4e61ce6182")) {                    Plotly.newPlot(                        "4d45aeed-f414-4478-887c-9a4e61ce6182",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Action\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Action"],"legendgroup":"Action","marker":{"color":"#1F77B4","size":[213.0],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Action","orientation":"v","showlegend":true,"x":[5.6],"xaxis":"x","y":[213.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Adventure\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Adventure"],"legendgroup":"Adventure","marker":{"color":"#FF7F0E","size":[39.0],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Adventure","orientation":"v","showlegend":true,"x":[6.5],"xaxis":"x","y":[39.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Animation\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Animation"],"legendgroup":"Animation","marker":{"color":"#2CA02C","size":[80.5],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Animation","orientation":"v","showlegend":true,"x":[6.25],"xaxis":"x","y":[80.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Biography\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Biography"],"legendgroup":"Biography","marker":{"color":"#D62728","size":[496.0],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Biography","orientation":"v","showlegend":true,"x":[6.95],"xaxis":"x","y":[496.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Comedy\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Comedy"],"legendgroup":"Comedy","marker":{"color":"#9467BD","size":[448.0],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Comedy","orientation":"v","showlegend":true,"x":[6.1],"xaxis":"x","y":[448.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Crime\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Crime"],"legendgroup":"Crime","marker":{"color":"#8C564B","size":[226.0],"sizemode":"area","sizeref":0.15888888888888889,"symbol":"circle"},"mode":"markers","name":"Crime","orientation":"v","showlegend":true,"x":[6.4],"xaxis":"x","y":[226.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ePrimary Genre=Documentary\u003cbr\u003eMed Rating=%{x}\u003cbr\u003eMed Votes=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Documentary"],"legendgroup":"Documentary","marker":{"color":"#E377C2","size":[46.0],"sizemode":"area","sizeref":0.158888 ...

# %% [markdown]
# #กราฟที่ 2

# %%
# สร้างกราฟ
fig = px.scatter(
    movie_df,
    x='Year',
    y='Duration',
    color='Primary Genre',  # ใช้สีเพื่อแยกประเภท
    size='Rating',  # ขนาดของฟองอากาศแสดงถึงคะแนน
    hover_name='Name',  # แสดงชื่อภาพยนตร์เมื่อ hover
    hover_data={'Year': True, 'Duration': True, 'Rating': True, 'Primary Genre': True},
    title='Relationship between Year and Duration',
    labels={'Duration': 'Duration (minutes)', 'Rating': 'Rating'},
    color_discrete_sequence=px.colors.qualitative.D3  # กำหนดสีเป็น D3
)

# ปรับแต่งกราฟ
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Duration (minutes)',
    coloraxis_colorbar=dict(title='Primary Genre'),
    template='plotly_white'
)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c113ff88-2dd7-4104-a6a5-6b2f4ae280b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c113ff88-2dd7-4104-a6a5-6b2f4ae280b8")) {                    Plotly.newPlot(                        "c113ff88-2dd7-4104-a6a5-6b2f4ae280b8",                        [{"customdata":[[7.0,"Drama"],[7.4,"Drama"],[6.2,"Drama"],[7.3,"Drama"],[7.1,"Drama"],[5.6,"Drama"],[4.5,"Drama"],[4.8,"Drama"],[7.7,"Drama"],[6.9,"Drama"],[6.9,"Drama"],[7.5,"Drama"],[5.6,"Drama"],[7.3,"Drama"],[4.8,"Drama"],[7.8,"Drama"],[6.2,"Drama"],[6.1,"Drama"],[4.1,"Drama"],[8.1,"Drama"],[6.3,"Drama"],[7.5,"Drama"],[4.5,"Drama"],[8.0,"Drama"],[7.3,"Drama"],[3.8,"Drama"],[7.9,"Drama"],[8.0,"Drama"],[6.8,"Drama"],[7.6,"Drama"],[6.4,"Drama"],[6.7,"Drama"],[6.8,"Drama"],[6.2,"Drama"],[5.0,"Drama"],[7.6,"Drama"],[5.4,"Drama"],[7.2,"Drama"],[6.0,"Drama"],[6.8,"Drama"],[5.5,"Drama"],[5.6,"Drama"],[6.2,"Drama"],[6.7,"Drama"],[6.9,"Drama"],[6.3,"Drama"],[7.7,"Drama"],[6.4,"Drama"],[6.4,"Drama"],[5.6,"Drama"],[8.1,"Drama"],[6.1,"Drama"],[7.4,"Drama"],[4.8,"Drama"],[6.6,"Drama"],[6.4,"Drama"],[5.7,"Drama"],[6.3,"Drama"],[6.2,"Drama"],[6.7,"Drama"],[5.4,"Drama"],[5.3,"Drama"],[7.1,"Drama"],[4.3,"Drama"],[7.0,"Drama"],[3.7,"Drama"],[7.3,"Drama"],[6.1,"Drama"],[3.8,"Drama"],[4.8,"Drama"],[5.5,"Drama"],[7.2,"Drama"],[6.4,"Drama"],[3.8,"Drama"],[7.0,"Drama"],[7.6,"Drama"],[4.0,"Drama"],[6.3,"Drama"],[6.8,"Drama"],[7.9,"Drama"],[6.7,"Drama"],[5.8,"Drama"],[6.5,"Drama"],[6.9,"Drama"],[4.7,"Drama"],[5.0,"Drama"],[3.3,"Drama"],[5.5,"Drama"],[5.8,"Drama"],[6.5,"Drama"],[7.8,"Drama"],[3.6,"Drama"],[5.9,"Drama"],[6.4,"Drama"],[7.1,"Drama"],[6.1,"Drama"],[4.6,"Drama"],[2.9,"Drama"],[5.9,"Drama"],[7.0,"Drama"],[5.7,"Drama"],[8.0,"Drama"],[6.6,"Drama"],[6.6,"Drama"],[5.8,"Drama"],[6.5,"Drama"],[6.7,"Drama"],[6.9,"Drama"],[6.3,"Drama"],[6.6,"Drama"],[7.7,"Drama"],[7.0,"Drama"],[4.8,"Drama"],[6.7,"Drama"],[6.8,"Drama"],[5.5,"Drama"],[5.9,"Drama"],[6.5,"Drama"],[7.0,"Drama"],[6.8,"Drama"],[6.1,"Drama"],[8.2,"Drama"],[4.4,"Drama"],[6.5,"Drama"],[6.2,"Drama"],[5.6,"Drama"],[7.0,"Drama"],[7.3,"Drama"],[5.9,"Drama"],[8.3,"Drama"],[7.1,"Drama"],[6.2,"Drama"],[5.3,"Drama"],[6.7,"Drama"],[5.5,"Drama"],[6.1,"Drama"],[7.2,"Drama"],[7.1,"Drama"],[6.9,"Drama"],[7.1,"Drama"],[6.5,"Drama"],[8.0,"Drama"],[5.6,"Drama"],[7.3,"Drama"],[7.0,"Drama"],[7.9,"Drama"],[7.1,"Drama"],[7.4,"Drama"],[6.3,"Drama"],[6.9,"Drama"],[6.4,"Drama"],[4.5,"Drama"],[6.6,"Drama"],[7.2,"Drama"],[5.5,"Drama"],[7.1,"Drama"],[6.7,"Drama"],[7.4,"Drama"],[6.6,"Drama"],[6.6,"Drama"],[6.7,"Drama"],[6.8,"Drama"],[6.6,"Drama"],[3.5,"Drama"],[6.2,"Drama"],[5.9,"Drama"],[6.5,"Drama"],[6.0,"Drama"],[6.8,"Drama"],[6.1,"Drama"],[7.3,"Drama"],[7.6,"Drama"],[6.5,"Drama"],[6.8,"Drama"],[5.2,"Drama"],[5.3,"Drama"],[6.2,"Drama"],[7.9,"Drama"],[6.9,"Drama"],[7.1,"Drama"],[4.9,"Drama"],[6.3,"Drama"],[7.6,"Drama"],[9.3,"Drama"],[4.3,"Drama"],[7.5,"Drama"],[7.3,"Drama"],[8.8,"Drama"],[6.0,"Drama"],[8.2,"Drama"],[3.8,"Drama"],[7.2,"Drama"],[4.2,"Drama"],[6.4,"Drama"],[6.5,"Drama"],[6.0,"Drama"],[7.2,"Drama"],[7.9,"Drama"],[5.9,"Drama"],[8.7,"Drama"],[6.2,"Drama"],[6.4,"Drama"],[7.1,"Drama"],[8.8,"Drama"],[2.1,"Drama"],[8.3,"Drama"],[5.4,"Drama"],[7.3,"Drama"],[6.1,"Drama"],[7.1,"Drama"],[7.3,"Drama"],[4.8,"Drama"],[5.9,"Drama"],[8.2,"Drama"],[6.7,"Drama"],[6.3,"Drama"],[6.0,"Drama"],[6.9,"Drama"],[5.4,"Drama"],[5.4,"Drama"],[6.7,"Drama"],[4.7,"Drama"],[6.6,"Drama"],[5.9,"Drama"],[7.7,"Drama"],[7.2,"Drama"],[7.4,"Drama"],[5.5,"Drama"],[5.7,"Drama"],[7.1,"Drama"],[7.6,"Drama"],[6.0,"Drama"],[6.5,"Drama"],[6.3,"Drama"],[6.8,"Drama"],[7.4,"Drama"],[6.8,"Drama"],[8.1,"Drama"],[3.2,"Drama"],[6.7,"Drama"],[6.1,"Drama"],[7.2,"Drama"],[7.1,"Drama"],[6.2,"Drama"],[7.7, ...
